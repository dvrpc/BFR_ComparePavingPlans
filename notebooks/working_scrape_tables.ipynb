# %%
from pathlib import Path
import tabula
import pandas as pd
from PyPDF2 import PdfFileReader
from sqlalchemy import create_engine
pd.options.mode.chained_assignment = None

# %%
file = "D:/dvrpc_shared/BFR_ComparePavingPlans/data/PDFs/Chester County Five Year Plan 2022-2026.pdf"
print(file)
# Out:
# D:/dvrpc_shared/BFR_ComparePavingPlans/data/PDFs/Chester County Five Year Plan 2022-2026.pdf

# %%
def get_number_of_pages_in_pdf(filepath):
    """
    Open a PDF file and return the number of pages within
    """
    with open(filepath, "rb") as pdf_file:
        pdf_reader = PdfFileReader(pdf_file)
        number_of_pages = pdf_reader.numPages

    return number_of_pages

# %%
def fill_empty_years(df):
    frames = []
    r = df.index[df['SR']=='Result']
    c = df.index[df['Year']=='Calendar year']

    for i in range(0, len(r)):
        page_start = 0
        if i == 0:
            chunk = df.iloc[page_start:r[i]]
            #starting from after the misplaced heading name
            year = df.iloc[c[0]+1]['Year']
            chunk['Year'].fillna(year, inplace=True)
            frames.append(chunk)
        else:
            chunk = df.iloc[r[i-1]+1:r[i]]
            year = df.iloc[r[i-1]+1]['Year']
            chunk['Year'].fillna(year, inplace=True)
            frames.append(chunk)

    allyears = pd.concat(frames, ignore_index=True)
    
    return allyears

# %%
def drop_total_results_row(df):
    for idx, row in df.iterrows():
        if row['Year'] =="Result":
            df.drop(idx, inplace=True)
        elif row
    return df

# %%
df['Year','Municipality3'].head()
# Out:
#   File "C:\Users\smoran\AppData\Local\Temp/ipykernel_19948/557549271.py", line 1
#     df['Year','Municipality3', axis=1].head()
#                                    ^
# SyntaxError: invalid syntax

# %%
def parse_single_page(file, page_number):

    table = tabula.read_pdf(file, pages=page_number, pandas_options={'header': None})[0]
    df = pd.DataFrame(table)

    #drop extra/empty columns (empty except header row)
    cols_to_drop = []
    for i in range(0, len(df.columns)):
        if df[i].isnull()[1:].all():
            cols_to_drop.append(i)

    if len(cols_to_drop) > 0:
        df.drop(cols_to_drop, axis=1, inplace=True)

    #rename columns
    column_names = ["Year", "SR", "Road Name", "From", "SegmentFrom", "OffsetFrom", "To", "SegmentTo", "OffsetTo", "Municipality1", "Municipality2", "Municipality3", "Miles Panned"]
    df.columns = column_names

    #fill in empty years
    df = fill_empty_years(df)

    #check number of rows header is read into (differs by file)
    if str(df['SR'][0]) == 'nan':
        rows_to_drop = [0,1]
        df.drop(rows_to_drop, inplace=True)

    else:
        rows_to_drop = [0]
        df.drop(rows_to_drop, inplace=True)

    #drop the last row with the plan total
    df = drop_total_results_row(df)

    return df

# %%
file = "D:/dvrpc_shared/BFR_ComparePavingPlans/data/PDFs/Delaware County Five Year Plan 2022-2026.pdf"
table = tabula.read_pdf(file, pages=2, pandas_options={'header': None})[0]
df = pd.DataFrame(table)

cols_to_drop = []
for i in range(0, len(df.columns)):
    if df[i].isnull()[1:].all():
        cols_to_drop.append(i)

if len(cols_to_drop) > 0:
    df.drop(cols_to_drop, axis=1, inplace=True)

column_names = ["Year", "SR", "Road Name", "From", "SegmentFrom", "OffsetFrom", "To", "SegmentTo", "OffsetTo", "Municipality1", "Municipality2", "Municipality3", "Miles Panned"]
df.columns = column_names

# %%
df.index[df['SR'].isnull()]
# Out:
# Int64Index([17, 18], dtype='int64')

# %%
frames = []
r = df.index[df['SR']=='Result']
n = df.index[df['SR'].isnull()]
c = df.index[df['Year']=='Calendar year']

print(r, n, c)
#if there is no total result row because they were left null, the nulls will be next to each other
#drop the second one from the list
if len(r) == 0:
    print("No r")
    if len(n) > 1:
        print("n is long enough")
        #if there is no total result row because they were left null, the nulls will be next to each other
        #drop the second one from the list
        if n[-1] - n[-2] == 1:
            n=n[:-1]
    r = n
    print(r)
# Out:
# Int64Index([], dtype='int64') Int64Index([17, 18], dtype='int64') Int64Index([0], dtype='int64')
# No r
# n is long enough
# Int64Index([17], dtype='int64')

# %%
if len(r) == 0:
    if len(n) > 1:
        #if there is no total result row because they were left null, the nulls will be next to each other
        #drop the second one from the list
        if n[-1] - n[-2] == 1:
            n=n[:-1]
    r = n
    for i in range(0, len(r)):
        page_start = 0
        if i == 0:
            chunk = df.iloc[page_start:r[i]]
            #starting from after the misplaced heading name
            year = df.iloc[c[0]+1]['Year']
            chunk['Year'].fillna(year, inplace=True)
            frames.append(chunk)
        else:
            chunk = df.iloc[r[i-1]+1:r[i]]
            year = df.iloc[r[i-1]+1]['Year']
            chunk['Year'].fillna(year, inplace=True)
            frames.append(chunk)
else: 
    for i in range(0, len(r)):
        page_start = 0
        if i == 0:
            chunk = df.iloc[page_start:r[i]]
            #starting from after the misplaced heading name
            year = df.iloc[c[0]+1]['Year']
            chunk['Year'].fillna(year, inplace=True)
            frames.append(chunk)
        else:
            chunk = df.iloc[r[i-1]+1:r[i]]
            year = df.iloc[r[i-1]+1]['Year']
            chunk['Year'].fillna(year, inplace=True)
            frames.append(chunk)

allyears = pd.concat(frames, ignore_index=True)
allyears.head()
# Out:
#             Year                            SR  \
# 0  Calendar year  State RouteLoc Road Name RMS
# 1           2026                          0202
# 2           2026                          0202
# 3           2026                          0291
# 4           2026                          0291
#
#                                            Road Name  \
# 0  LOCATION FROM\rIntersection FromSegment FromOf...
# 1                                      WILMINGTON PK
# 2                                      WILMINGTON PK
# 3                                      INDUSTRIAL HW
# 4                                      INDUSTRIAL HW
#
#                                               From         SegmentFrom  \
# 0  LOCATION TO\rIntersection ToSegment ToOffset To  Municipality Name1
# 1                           Baltimore Pk / SR 0001                0090
# 2                           Baltimore Pk / SR 0001                0091
# 3                320' E of Eddystone Industrial Ct                0114
# 4                320' E of Eddystone Industrial Ct                0115
#
#            OffsetFrom                                            To  \
# 0  Municipality Name2                            Municipality Name3
# 1                0000  Dilworthtown Rd / SR 4016 / Chester Co. Line
# 2                0000  Dilworthtown Rd / SR 4016 / Chester Co. Line
# 3                0000                                   Stevens Dr.
# 4                0000                                   Stevens Dr.
#
#         SegmentTo  OffsetTo Municipality1 Municipality2 Municipality3  \
# 0  Miles\rPlanned       NaN           NaN           NaN           NaN
# 1            0116    2108.0       CONCORD   CHADDS FORD           NaN
# 2            0117    2372.0       CONCORD   CHADDS FORD           NaN
# 3            0180    3053.0     EDDYSTONE       TINICUM        RIDLEY
# 4            0181    3043.0     EDDYSTONE       TINICUM        RIDLEY
#
#    Miles Panned
# 0           NaN
# 1          1.66
# 2          1.65
# 3          3.22
# 4          3.23

# %%
page1 = parse_single_page(file, 1)
#page2 = parse_single_page(file, 2)
#page2.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19948/3158762220.py in <module>
# ----> 1 page1 = parse_single_page(file, 1)
#       2 #page2 = parse_single_page(file, 2)
#       3 #page2.head()
#
# ~\AppData\Local\Temp/ipykernel_19948/3730465818.py in parse_single_page(file, page_number)
#      14
#      15     #fill in empty years
# ---> 16     df = fill_empty_years(df)
#      17
#      18     #check number of rows header is read into (differs by file)
#
# ~\AppData\Local\Temp/ipykernel_19948/1208042167.py in fill_empty_years(df)
#      18             frames.append(chunk)
#      19
# ---> 20     allyears = pd.concat(frames, ignore_index=True)
#      21
#      22     return allyears
#
# ~\Anaconda3\envs\bfr_compare_paving_plans\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\envs\bfr_compare_paving_plans\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# ~\Anaconda3\envs\bfr_compare_paving_plans\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     349
#     350         if len(objs) == 0:
# --> 351             raise ValueError("No objects to concatenate")
#     352
#     353         if keys is None:
#
# ValueError: No objects to concatenate

# %%
def parse_all_pdfs(county):
    file = fr"D:/dvrpc_shared/BFR_ComparePavingPlans/data/PDFs/{county} County Five Year Plan 2022-2026.pdf"
    frames = []
    num_pages = get_number_of_pages_in_pdf(file)
    for i in range(1, num_pages+1):
        df = parse_single_page(file, page_number=i)
        frames.append(df)

    allpgs = pd.concat(frames, ignore_index=True)

    output_filepath = fr"D:/dvrpc_shared/BFR_ComparePavingPlans/data/CSVs/{county}_fiveyearplan_2022_2026.csv"

    allpgs.to_csv(output_filepath, index=False)
    allpgs.to_sql(f"{county}_County_Plan", ENGINE, if_exists="replace")


counties = ["Bucks", "Chester", "Delaware", "Montgomery", "Philadelphia"]

for county in counties:
    parse_all_pdfs(county)

# %%
test = fill_empty_years(df)
test.head()
# Out:
# 2022
# 2023
# 2024
# 2025
#             Year                            SR  \
# 0  Calendar year  State RouteLoc Road Name RMS
# 1           2022                          0232
# 2           2022                          0313
# 3           2022                          0313
# 4           2022                          0313
#
#                                            Road Name  \
# 0  LOCATION FROM\rIntersection FromSegment FromOf...
# 1                                    SECOND STREET P
# 2                                          DUBLIN PK
# 3                                           SWAMP RD
# 4                                           SWAMP RD
#
#                                               From         SegmentFrom  \
# 0  LOCATION TO\rIntersection ToSegment ToOffset To  Municipality Name1
# 1                           Bustleton Pk / SR 2065                0094
# 2                            Morgan Creek / Bridge                0082
# 3           Bedminster Rd / Souderton Rd / SR 0113                0222
# 4                          Curly Hill Rd / SR 1008                0292
#
#            OffsetFrom                                      To       SegmentTo  \
# 0  Municipality Name2                      Municipality Name3  Miles\rPlanned
# 1                0000                      Swamp Rd / SR 2036            0150
# 2                0000  Bedminster Rd / Souderton Rd / SR 0113            0212
# 3                0000                 Curly Hill Rd / SR 1008            0282
# 4                0000        Doylestown / Plumstead Twp. Line            0342
#
#    OffsetTo Municipality1 Municipality2  Municipality3  Miles Panned
# 0       NaN           NaN           NaN            NaN           NaN
# 1    1676.0   WRIGHTSTOWN   NORTHAMPTON            NaN          3.09
# 2    1500.0      RICHLAND      HILLTOWN  EAST ROCKHILL          6.40
# 3    2345.0        DUBLIN   NEW BRITAIN       HILLTOWN          3.72
# 4     948.0   NEW BRITAIN    DOYLESTOWN            NaN          2.09

# %%
column_names = ["Year", "SR", "Road Name", "From", "SegmentFrom", "OffsetFrom", "To", "SegmentTo", "OffsetTo", "Municipality1", "Municipality2", "Municipality3", "Miles Panned"]

# %%
len(df)
# Out:
# 78

# %%
table = tabula.read_pdf(file, pages=1, pandas_options={'header': None})[0]
df = pd.DataFrame(table)

col_to_drop = [4, 8]
df.drop(col_to_drop, axis=1, inplace=True)

df.columns=column_names
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19948/3058849651.py in <module>
#       5 df.drop(col_to_drop, axis=1, inplace=True)
#       6
# ----> 7 df.columns=column_names
#       8 df.head()
#       9
#
# ~\Anaconda3\envs\bfr_compare_paving_plans\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~\Anaconda3\envs\bfr_compare_paving_plans\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\envs\bfr_compare_paving_plans\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~\Anaconda3\envs\bfr_compare_paving_plans\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~\Anaconda3\envs\bfr_compare_paving_plans\lib\site-packages\pandas\core\internals\base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 11 elements, new values have 13 elements
